# %%
#firstly, we import pandas in order to work with the data set
import pandas as pd
import numpy as np

#First step from creating the model is to import the important library for machine learning, which in our situation is scikit-learn.
import sklearn as scikit_learn
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

# %%
#secondly, we have to configure the file path in order to load the data f
# Load the dataset
file_path = "Data/set8_it1.csv"  # Update with your file path
df = pd.read_csv(file_path)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2363 entries, 0 to 2362
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   DI              2363 non-null   int64
#  1   TradeValue      2363 non-null   float64
#  2   RealmType       2363 non-null   object
#  3   Enclave         2363 non-null   object
#  4   LivingQuarters  2244 non-null   float64
#  5   ParcelSize      2363 non-null   float64
#  6   ParcelSizeUnit  2363 non-null   object
# dtypes: float64(3), int64(1), object(3)
# memory usage: 129.4+ KB

# %%
# 1. Remove negative values in ParcelSize
df = df[df["ParcelSize"] >= 10]

# %%
# 2. Remove rows with missing LivingQuarters data
df["LivingQuarters"] = df["LivingQuarters"].fillna(df["LivingQuarters"].median())

# %%
# 3. Remove rows where ParcelSize is less than 1
#df = df[df["ParcelSize"] >= 1]

# %%
# 4. Remove duplicate rows
df = df.drop_duplicates()

# %%
# 5. Standardize Enclave column (lowercase and strip spaces)
df["Enclave"] = df["Enclave"].str.strip().str.lower()
# Define a mapping to correct similar enclave names
enclave_corrections = {
    "shadowmeres": "shadowmere",
    "mystvales": "mystvale",
    "dragonspires": "dragonspire",
    "stormwatchs": "stormwatch",
    "thornfields": "thornfield",
    "petalbridges": "petalbridge",
    "silverglens": "silverglen",
    "riverbends": "riverbend",
    "emberfalls": "emberfall"
}

# Replace incorrect names with correct ones
df["Enclave"] = df["Enclave"].replace(enclave_corrections)

# Verify the results
df["Enclave"].unique()
# Out:
# array(['shadowmere', 'ravenstone', 'petalbridge', 'emberfall',
#        'dragonspire', 'riverbend', 'cloudrest', 'sunspire', 'nighthaven',
#        'brightforge', 'wyverncliff', 'crystalhollow', 'wolfsbane',
#        'duskwood', 'mystvale', 'glimmerwood', 'stormhold', 'starfall',
#        'silverglen', 'thornfield', 'dreamweaver', 'stormwatch',
#        'windwhisper', 'oakenshade', 'mossheart', 'verdantia', 'moonglade'],
#       dtype=object)

# %%
# 6. Convert ParcelSize to sqft if it is in sqm
conversion_factor = 10.7639  # 1 sqm = 10.7639 sqft
df.loc[df["ParcelSizeUnit"] == "sqm", "ParcelSize"] *= conversion_factor
df.loc[df["ParcelSizeUnit"] == "sqm", "ParcelSizeUnit"] = "sqft"  # Standardizing to sqft

# %%
# 7. Investigate TradeValue minimum
min_trade_value = df["TradeValue"].min()
outlier_trade_value = df[df["TradeValue"] == min_trade_value]

# %%
# 8. Detect outliers using 1.5*IQR method
def detect_outliers(column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] < lower_bound) & (df[column] > upper_bound)]

# %%
outliers_trade_value = detect_outliers("TradeValue")
outliers_living_quarters = detect_outliers("LivingQuarters")
outliers_parcel_size = detect_outliers("ParcelSize")

# Get index values of all outliers
outlier_indices = (
    outliers_trade_value.index.to_list() + 
    outliers_living_quarters.index.to_list() + 
    outliers_parcel_size.index.to_list()
)

# Drop these rows from the dataset
df = df.drop(index=outlier_indices)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2318 entries, 0 to 2362
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   DI              2318 non-null   int64
#  1   TradeValue      2318 non-null   float64
#  2   RealmType       2318 non-null   object
#  3   Enclave         2318 non-null   object
#  4   LivingQuarters  2318 non-null   float64
#  5   ParcelSize      2318 non-null   float64
#  6   ParcelSizeUnit  2318 non-null   object
# dtypes: float64(3), int64(1), object(3)
# memory usage: 144.9+ KB

# %%
df
# Out:
#         DI  TradeValue     RealmType      Enclave  LivingQuarters  ParcelSize  \
# 0        0    125000.0   Meadowlands   shadowmere          1032.0      9280.0
# 1        1    250000.0   Meadowlands   ravenstone          1933.0     11170.0
# 2        2    130000.0  GnomeBurough  petalbridge          1012.0      5500.0
# 3        3    157500.0   Meadowlands    emberfall           843.0     13014.0
# 4        4    156000.0   Meadowlands  dragonspire           807.0      8092.0
# ...    ...         ...           ...          ...             ...         ...
# 2358  2335    135000.0   Meadowlands  dragonspire          1110.5      8064.0
# 2359  2336    334000.0   Meadowlands  glimmerwood          2173.0     11025.0
# 2360  2337    214000.0   Meadowlands  dragonspire          1138.0      8197.0
# 2361  2338    129500.0   Meadowlands    emberfall           759.0      9100.0
# 2362  2339    153500.0   Meadowlands   nighthaven           826.0     10140.0
#
#      ParcelSizeUnit
# 0              sqft
# 1              sqft
# 2              sqft
# 3              sqft
# 4              sqft
# ...             ...
# 2358           sqft
# 2359           sqft
# 2360           sqft
# 2361           sqft
# 2362           sqft
#
# [2318 rows x 7 columns]

# %%
# The next step is to connect the prepared data from above and to use it for getting the mean and median of the TradeValue variable. 
mean_trade_value = df['TradeValue'].mean()
median_trade_value = df['TradeValue'].median()

# %%
#After we have connected the data, we are transforming the categorical data into numerical using the label encoder so the model can fit all of that information so it can make predictions
label_encoder_realm = LabelEncoder()
label_encoder_enclave = LabelEncoder()
df['RealmType'] = label_encoder_realm.fit_transform(df['RealmType'])
df['Enclave'] = label_encoder_enclave.fit_transform(df['Enclave'])

# %%
#After that we separate our data into two categories: categorical data, which we transform and data we want to predict. They are separated in X, y respectively
X = df.drop(['TradeValue', 'ParcelSizeUnit'], axis=1)
y = df['TradeValue']

# %%
#Then we assign the data, where we are using 80% of the data for training
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
#The final step is we have created the model, fit in the data and trained it to make predictions
value = y_train.median()
pred_train = [value] * len(y_train)
pred_test = [value] * len(y_test)

# %%
#After the predictions we are using metrics such as Mean Absolute Error and Mean squared error to see what the efficiency of our model is
mae = mean_absolute_error(y_test, pred_test) 
mse = mean_squared_error(y_test, pred_test)

# %%
mae
# Out:
# 54498.995689655174

# %%
mean_absolute_percentage_error(y_test, pred_test)
# Out:
# 0.297256762750289

# %%
mse
# Out:
# 6533157540.837644

# %%
df2 = df.copy()
df2 = df2.drop(columns=["ParcelSizeUnit"])
df2.corr()
# Out:
#                                 DI  TradeValue  LivingQuarters  ParcelSize  \
# DI                        1.000000   -0.013513       -0.038318   -0.003256
# TradeValue               -0.013513    1.000000        0.688021    0.280705
# LivingQuarters           -0.038318    0.688021        1.000000    0.316218
# ParcelSize               -0.003256    0.280705        0.316218    1.000000
# RealmType_AetherIsles    -0.022226    0.098747        0.022784   -0.110437
# RealmType_ArcaneMarket   -0.015078   -0.121960       -0.072958   -0.025366
# RealmType_CitadelQuarter -0.014958   -0.055734       -0.006305   -0.033324
# RealmType_GnomeBurough    0.008969   -0.291689       -0.148523   -0.223058
# RealmType_Meadowlands     0.009959    0.244519        0.136111    0.265184
# Enclave_brightforge      -0.028587    0.004964        0.054269   -0.002592
# Enclave_cloudrest        -0.012104   -0.046291       -0.044556   -0.091082
# Enclave_crystalhollow    -0.003851   -0.044478       -0.071349    0.042646
# Enclave_dragonspire      -0.008830   -0.189504       -0.167368   -0.003498
# Enclave_dreamweaver       0.021393    0.012378       -0.023665   -0.093654
# Enclave_duskwood          0.018582    0.022164        0.043229    0.038470
# Enclave_emberfall         0.026274   -0.124764       -0.142504    0.015636
# Enclave_glimmerwood      -0.006140    0.292706        0.298685    0.062441
# Enclave_moonglade         0.026366    0.035024       -0.006072   -0.004349
# Enclave_mossheart         0.001044    0.076645        0.054557    0.079131
# Enclave_mystvale         -0.019186   -0.168758       -0.106507   -0.049868
# Enclave_nighthaven       -0.018359    0.017248        0.075541    0.049912
# Enclave_oakenshade        0.036067   -0.027733       -0.045132   -0.066273
# Enclave_petalbridge       0.001016   -0.206188       -0.037196   -0.075219
# Enclave_ravenstone        0.040364    0.131002        0.058836    0.116376
# Enclave_riverbend        -0.032486    0.248349        0.110738    0.019050
# Enclave_shadowmere       -0.019359   -0.156626       -0.062455    0.025562
# Enclave_silverglen        0.038561    0.445965        0.222206    0.042312
# Enclave_starfall         -0.005975   -0.096088       -0.076832   -0.119766
# Enclave_stormhold        -0.001587   -0.075548        0.029269   -0.043778
# Enclave_stormwatch       -0.001053   -0.141847       -0.102526   -0.084095
# Enclave_sunspire         -0.007430    0.072749       -0.006923   -0.004753
# Enclave_thornfield        0.020282    0.057412        0.082652    0.041884
# Enclave_verdantia         0.026842    0.003050       -0.037471   -0.043693
# Enclave_windwhisper       0.011860    0.046811        0.069896    0.284710
# Enclave_wolfsbane        -0.002136   -0.120750       -0.089897   -0.127549
# Enclave_wyverncliff      -0.023617    0.153837        0.042832   -0.088577
#
#                           RealmType_AetherIsles  RealmType_ArcaneMarket  \
# DI                                    -0.022226               -0.015078
# TradeValue                             0.098747               -0.121960
# LivingQuarters                         0.022784               -0.072958
# ParcelSize                            -0.110437               -0.025366
# RealmType_AetherIsles                  1.000000               -0.020291
# RealmType_ArcaneMarket                -0.020291                1.000000
# RealmType_CitadelQuarter              -0.020291               -0.008264
# RealmType_GnomeBurough                -0.097275               -0.039620
# RealmType_Meadowlands                 -0.416072               -0.169464
# Enclave_brightforge                   -0.047145               -0.019202
# Enclave_cloudrest                     -0.019746               -0.008042
# Enclave_crystalhollow                 -0.044339               -0.018059
# Enclave_dragonspire                   -0.093969               -0.038273
# Enclave_dreamweaver                   -0.022344               -0.009101
# Enclave_duskwood                      -0.054184               -0.022069
# Enclave_emberfall                     -0.051461               -0.020960
# Enclave_glimmerwood                   -0.034797               -0.014172
# Enclave_moonglade                     -0.006559               -0.002671
# Enclave_mossheart                     -0.020291               -0.008264
# Enclave_mystvale                      -0.039676                0.483655
# Enclave_nighthaven                    -0.047640               -0.019404
# Enclave_oakenshade                    -0.013935               -0.005676
# Enclave_petalbridge                   -0.066503               -0.027086
# Enclave_ravenstone                    -0.035119               -0.014304
# Enclave_riverbend                     -0.030686               -0.012498
# Enclave_shadowmere                    -0.059956               -0.024420
# Enclave_silverglen                    -0.054627               -0.022249
# Enclave_starfall                      -0.023306               -0.009492
# Enclave_stormhold                     -0.029577                0.024695
# Enclave_stormwatch                    -0.044339               -0.018059
# Enclave_sunspire                      -0.071184               -0.028993
# Enclave_thornfield                    -0.041926               -0.017076
# Enclave_verdantia                     -0.011370               -0.004631
# Enclave_windwhisper                   -0.027636               -0.011256
# Enclave_wolfsbane                     -0.025558               -0.010410
# Enclave_wyverncliff                    0.860895               -0.023570
#
#                           RealmType_CitadelQuarter  RealmType_GnomeBurough  \
# DI                                       -0.014958                0.008969
# TradeValue                               -0.055734               -0.291689
# LivingQuarters                           -0.006305               -0.148523
# ParcelSize                               -0.033324               -0.223058
# RealmType_AetherIsles                    -0.020291               -0.097275
# RealmType_ArcaneMarket                   -0.008264               -0.039620
# RealmType_CitadelQuarter                  1.000000               -0.039620
# RealmType_GnomeBurough                   -0.039620                1.000000
# RealmType_Meadowlands                    -0.169464               -0.812415
# Enclave_brightforge                       0.099113               -0.092055
# Enclave_cloudrest                        -0.008042               -0.038555
# Enclave_crystalhollow                    -0.018059               -0.043431
# Enclave_dragonspire                       0.028623               -0.183483
# Enclave_dreamweaver                      -0.009101               -0.031745
# Enclave_duskwood                         -0.022069               -0.105798
# Enclave_emberfall                        -0.020960               -0.084341
# Enclave_glimmerwood                      -0.014172               -0.067943
# Enclave_moonglade                        -0.002671                0.067428
# Enclave_mossheart                        -0.008264               -0.039620
# Enclave_mystvale                         -0.016160                0.284826
# Enclave_nighthaven                       -0.019404               -0.093022
# Enclave_oakenshade                       -0.005676                0.143253
# Enclave_petalbridge                      -0.027086                0.541614
# Enclave_ravenstone                       -0.014304               -0.068573
# Enclave_riverbend                        -0.012498               -0.059917
# Enclave_shadowmere                        0.013775               -0.065353
# Enclave_silverglen                       -0.022249               -0.101563
# Enclave_starfall                         -0.009492                0.239586
# Enclave_stormhold                         0.171662               -0.057751
# Enclave_stormwatch                       -0.018059                0.240088
# Enclave_sunspire                         -0.028993               -0.094233
# Enclave_thornfield                        0.035666               -0.029928
# Enclave_verdantia                        -0.004631               -0.022202
# Enclave_windwhisper                      -0.011256               -0.053962
# Enclave_wolfsbane                        -0.010410                0.262740
# Enclave_wyverncliff                      -0.023570               -0.112993
#
#                           RealmType_Meadowlands  Enclave_brightforge  ...  \
# DI                                     0.009959            -0.028587  ...
# TradeValue                             0.244519             0.004964  ...
# LivingQuarters                         0.136111             0.054269  ...
# ParcelSize                             0.265184            -0.002592  ...
# RealmType_AetherIsles                 -0.416072            -0.047145  ...
# RealmType_ArcaneMarket                -0.169464            -0.019202  ...
# RealmType_CitadelQuarter              -0.169464             0.099113  ...
# RealmType_GnomeBurough                -0.812415            -0.092055  ...
# RealmType_Meadowlands                  1.000000             0.087701  ...
# Enclave_brightforge                    0.087701             1.000000  ...
# Enclave_cloudrest                      0.047457            -0.018686  ...
# Enclave_crystalhollow                  0.068633            -0.041959  ...
# Enclave_dragonspire                    0.211370            -0.088926  ...
# Enclave_dreamweaver                    0.043255            -0.021145  ...
# Enclave_duskwood                       0.130227            -0.051276  ...
# Enclave_emberfall                      0.109492            -0.048699  ...
# Enclave_glimmerwood                    0.083631            -0.032929  ...
# Enclave_moonglade                     -0.054779            -0.006207  ...
# Enclave_mossheart                      0.048768            -0.019202  ...
# Enclave_mystvale                      -0.331359            -0.037546  ...
# Enclave_nighthaven                     0.114500            -0.045083  ...
# Enclave_oakenshade                    -0.116381            -0.013187  ...
# Enclave_petalbridge                   -0.430527            -0.062934  ...
# Enclave_ravenstone                     0.084407            -0.033234  ...
# Enclave_riverbend                      0.073752            -0.029039  ...
# Enclave_shadowmere                     0.090364            -0.056738  ...
# Enclave_silverglen                     0.126808            -0.051695  ...
# Enclave_starfall                      -0.194643            -0.022055  ...
# Enclave_stormhold                      0.023370            -0.027989  ...
# Enclave_stormwatch                    -0.180641            -0.041959  ...
# Enclave_sunspire                       0.131733            -0.067363  ...
# Enclave_thornfield                     0.043688            -0.039676  ...
# Enclave_verdantia                      0.027328            -0.010760  ...
# Enclave_windwhisper                    0.066422            -0.026153  ...
# Enclave_wolfsbane                     -0.213454            -0.024186  ...
# Enclave_wyverncliff                   -0.329837            -0.054763  ...
#
#                           Enclave_silverglen  Enclave_starfall  \
# DI                                  0.038561         -0.005975
# TradeValue                          0.445965         -0.096088
# LivingQuarters                      0.222206         -0.076832
# ParcelSize                          0.042312         -0.119766
# RealmType_AetherIsles              -0.054627         -0.023306
# RealmType_ArcaneMarket             -0.022249         -0.009492
# RealmType_CitadelQuarter           -0.022249         -0.009492
# RealmType_GnomeBurough             -0.101563          0.239586
# RealmType_Meadowlands               0.126808         -0.194643
# Enclave_brightforge                -0.051695         -0.022055
# Enclave_cloudrest                  -0.021651         -0.009237
# Enclave_crystalhollow              -0.048618         -0.020742
# Enclave_dragonspire                -0.103039         -0.043960
# Enclave_dreamweaver                -0.024501         -0.010453
# Enclave_duskwood                   -0.059413         -0.025348
# Enclave_emberfall                  -0.056428         -0.024074
# Enclave_glimmerwood                -0.038155         -0.016278
# Enclave_moonglade                  -0.007192         -0.003068
# Enclave_mossheart                  -0.022249         -0.009492
# Enclave_mystvale                   -0.043505         -0.018561
# Enclave_nighthaven                 -0.052238         -0.022287
# Enclave_oakenshade                 -0.015280         -0.006519
# Enclave_petalbridge                -0.072921         -0.031111
# Enclave_ravenstone                 -0.038509         -0.016429
# Enclave_riverbend                  -0.033648         -0.014355
# Enclave_shadowmere                 -0.065742         -0.028048
# Enclave_silverglen                  1.000000         -0.025555
# Enclave_starfall                   -0.025555          1.000000
# Enclave_stormhold                  -0.032431         -0.013836
# Enclave_stormwatch                 -0.048618         -0.020742
# Enclave_sunspire                   -0.078054         -0.033301
# Enclave_thornfield                 -0.045972         -0.019613
# Enclave_verdantia                  -0.012468         -0.005319
# Enclave_windwhisper                -0.030303         -0.012929
# Enclave_wolfsbane                  -0.028025         -0.011956
# Enclave_wyverncliff                -0.063454         -0.027072
#
#                           Enclave_stormhold  Enclave_stormwatch  \
# DI                                -0.001587           -0.001053
# TradeValue                        -0.075548           -0.141847
# LivingQuarters                     0.029269           -0.102526
# ParcelSize                        -0.043778           -0.084095
# RealmType_AetherIsles             -0.029577           -0.044339
# RealmType_ArcaneMarket             0.024695           -0.018059
# RealmType_CitadelQuarter           0.171662           -0.018059
# RealmType_GnomeBurough            -0.057751            0.240088
# RealmType_Meadowlands              0.023370           -0.180641
# Enclave_brightforge               -0.027989           -0.041959
# Enclave_cloudrest                 -0.011723           -0.017574
# Enclave_crystalhollow             -0.026323           -0.039462
# Enclave_dragonspire               -0.055788           -0.083633
# Enclave_dreamweaver               -0.013266           -0.019887
# Enclave_duskwood                  -0.032168           -0.048224
# Enclave_emberfall                 -0.030552           -0.045801
# Enclave_glimmerwood               -0.020658           -0.030969
# Enclave_moonglade                 -0.003894           -0.005838
# Enclave_mossheart                 -0.012046           -0.018059
# Enclave_mystvale                  -0.023555           -0.035312
# Enclave_nighthaven                -0.028283           -0.042400
# Enclave_oakenshade                -0.008273           -0.012402
# Enclave_petalbridge               -0.039482           -0.059188
# Enclave_ravenstone                -0.020850           -0.031256
# Enclave_riverbend                 -0.018218           -0.027311
# Enclave_shadowmere                -0.035595           -0.053361
# Enclave_silverglen                -0.032431           -0.048618
# Enclave_starfall                  -0.013836           -0.020742
# Enclave_stormhold                  1.000000           -0.026323
# Enclave_stormwatch                -0.026323            1.000000
# Enclave_sunspire                  -0.042261           -0.063354
# Enclave_thornfield                -0.024891           -0.037314
# Enclave_verdantia                 -0.006750           -0.010120
# Enclave_windwhisper               -0.016407           -0.024596
# Enclave_wolfsbane                 -0.015173           -0.022747
# Enclave_wyverncliff               -0.034356           -0.051503
#
#                           Enclave_sunspire  Enclave_thornfield  \
# DI                               -0.007430            0.020282
# TradeValue                        0.072749            0.057412
# LivingQuarters                   -0.006923            0.082652
# ParcelSize                       -0.004753            0.041884
# RealmType_AetherIsles            -0.071184           -0.041926
# RealmType_ArcaneMarket           -0.028993           -0.017076
# RealmType_CitadelQuarter         -0.028993            0.035666
# RealmType_GnomeBurough           -0.094233           -0.029928
# RealmType_Meadowlands             0.131733            0.043688
# Enclave_brightforge              -0.067363           -0.039676
# Enclave_cloudrest                -0.028213           -0.016617
# Enclave_crystalhollow            -0.063354           -0.037314
# Enclave_dragonspire              -0.134268           -0.079082
# Enclave_dreamweaver              -0.031927           -0.018804
# Enclave_duskwood                 -0.077421           -0.045599
# Enclave_emberfall                -0.073530           -0.043308
# Enclave_glimmerwood              -0.049719           -0.029284
# Enclave_moonglade                -0.009372           -0.005520
# Enclave_mossheart                -0.028993           -0.017076
# Enclave_mystvale                 -0.056691           -0.033390
# Enclave_nighthaven               -0.068071           -0.040093
# Enclave_oakenshade               -0.019911           -0.011727
# Enclave_petalbridge              -0.095023           -0.055967
# Enclave_ravenstone               -0.050180           -0.029555
# Enclave_riverbend                -0.043846           -0.025824
# Enclave_shadowmere               -0.085668           -0.050457
# Enclave_silverglen               -0.078054           -0.045972
# Enclave_starfall                 -0.033301           -0.019613
# Enclave_stormhold                -0.042261           -0.024891
# Enclave_stormwatch               -0.063354           -0.037314
# Enclave_sunspire                  1.000000           -0.059906
# Enclave_thornfield               -0.059906            1.000000
# Enclave_verdantia                -0.016247           -0.009569
# Enclave_windwhisper              -0.039488           -0.023258
# Enclave_wolfsbane                -0.036519           -0.021509
# Enclave_wyverncliff              -0.082686           -0.048700
#
#                           Enclave_verdantia  Enclave_windwhisper  \
# DI                                 0.026842             0.011860
# TradeValue                         0.003050             0.046811
# LivingQuarters                    -0.037471             0.069896
# ParcelSize                        -0.043693             0.284710
# RealmType_AetherIsles             -0.011370            -0.027636
# RealmType_ArcaneMarket            -0.004631            -0.011256
# RealmType_CitadelQuarter          -0.004631            -0.011256
# RealmType_GnomeBurough            -0.022202            -0.053962
# RealmType_Meadowlands              0.027328             0.066422
# Enclave_brightforge               -0.010760            -0.026153
# Enclave_cloudrest                 -0.004507            -0.010954
# Enclave_crystalhollow             -0.010120            -0.024596
# Enclave_dragonspire               -0.021447            -0.052128
# Enclave_dreamweaver               -0.005100            -0.012395
# Enclave_duskwood                  -0.012367            -0.030058
# Enclave_emberfall                 -0.011745            -0.028547
# Enclave_glimmerwood               -0.007942            -0.019303
# Enclave_moonglade                 -0.001497            -0.003639
# Enclave_mossheart                 -0.004631            -0.011256
# Enclave_mystvale                  -0.009055            -0.022009
# Enclave_nighthaven                -0.010873            -0.026428
# Enclave_oakenshade                -0.003180            -0.007730
# Enclave_petalbridge               -0.015178            -0.036891
# Enclave_ravenstone                -0.008015            -0.019482
# Enclave_riverbend                 -0.007004            -0.017023
# Enclave_shadowmere                -0.013684            -0.033259
# Enclave_silverglen                -0.012468            -0.030303
# Enclave_starfall                  -0.005319            -0.012929
# Enclave_stormhold                 -0.006750            -0.016407
# Enclave_stormwatch                -0.010120            -0.024596
# Enclave_sunspire                  -0.016247            -0.039488
# Enclave_thornfield                -0.009569            -0.023258
# Enclave_verdantia                  1.000000            -0.006308
# Enclave_windwhisper               -0.006308             1.000000
# Enclave_wolfsbane                 -0.005833            -0.014178
# Enclave_wyverncliff               -0.013208            -0.032102
#
#                           Enclave_wolfsbane  Enclave_wyverncliff
# DI                                -0.002136            -0.023617
# TradeValue                        -0.120750             0.153837
# LivingQuarters                    -0.089897             0.042832
# ParcelSize                        -0.127549            -0.088577
# RealmType_AetherIsles             -0.025558             0.860895
# RealmType_ArcaneMarket            -0.010410            -0.023570
# RealmType_CitadelQuarter          -0.010410            -0.023570
# RealmType_GnomeBurough             0.262740            -0.112993
# RealmType_Meadowlands             -0.213454            -0.329837
# Enclave_brightforge               -0.024186            -0.054763
# Enclave_cloudrest                 -0.010130            -0.022936
# Enclave_crystalhollow             -0.022747            -0.051503
# Enclave_dragonspire               -0.048208            -0.109153
# Enclave_dreamweaver               -0.011463            -0.025955
# Enclave_duskwood                  -0.027797            -0.062939
# Enclave_emberfall                 -0.026401            -0.059776
# Enclave_glimmerwood               -0.017851            -0.040419
# Enclave_moonglade                 -0.003365            -0.007619
# Enclave_mossheart                 -0.010410            -0.023570
# Enclave_mystvale                  -0.020354            -0.046087
# Enclave_nighthaven                -0.024441            -0.055338
# Enclave_oakenshade                -0.007149            -0.016187
# Enclave_petalbridge               -0.034117            -0.077248
# Enclave_ravenstone                -0.018017            -0.040794
# Enclave_riverbend                 -0.015743            -0.035644
# Enclave_shadowmere                -0.030759            -0.069644
# Enclave_silverglen                -0.028025            -0.063454
# Enclave_starfall                  -0.011956            -0.027072
# Enclave_stormhold                 -0.015173            -0.034356
# Enclave_stormwatch                -0.022747            -0.051503
# Enclave_sunspire                  -0.036519            -0.082686
# Enclave_thornfield                -0.021509            -0.048700
# Enclave_verdantia                 -0.005833            -0.013208
# Enclave_windwhisper               -0.014178            -0.032102
# Enclave_wolfsbane                  1.000000            -0.029688
# Enclave_wyverncliff               -0.029688             1.000000
#
# [36 rows x 36 columns]
