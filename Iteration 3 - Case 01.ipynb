# %%
# General & data preparation
import pandas as pd

# Data vizualization
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Model and evaluation
import sklearn as scikit_learn
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %%
# Load the datasets
df_it1 = pd.read_csv("Data//set8_it1_cleaned.xls", sep=',')
df_it2 = pd.read_csv("Data//set8_it2.csv")
df_it3 = pd.read_csv("Data//set8_it3.csv")

# %% [markdown]
# ## **DATA UNDERSTANDING - add on dataset**

# %%
df_it2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2363 entries, 0 to 2362
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DI                   2363 non-null   int64
#  1   StructuralIntegrity  2363 non-null   int64
#  2   ExteriorCharm        2363 non-null   object
# dtypes: int64(2), object(1)
# memory usage: 55.5+ KB

# %% [markdown]
# ## **DATA PREPARATION**
# * Initial merging of the cleaned dataset and the add-on dataset
# * Cleaning duplicates to not have any missing values
# * Setting initial calculations based on the income, loan, downpayments, etc

# %%
# Remove duplicate rows
df_it2 = df_it2.drop_duplicates()
df_it3 = df_it3.drop_duplicates()

# %%
# left merge on the cleaned dataset
df = df_it1.merge(df_it2, on='DI', how='left')
df = df.merge(df_it3, on='DI', how='left')

# %%
df
# Out:
#         DI  TradeValue     RealmType      Enclave  LivingQuarters  ParcelSize  \
# 0        0    125000.0   Meadowlands   Shadowmere          1032.0      9280.0
# 1        1    250000.0   Meadowlands   Ravenstone          1933.0     11170.0
# 2        2    130000.0  GnomeBurough  Petalbridge          1012.0      5500.0
# 3        3    157500.0   Meadowlands    Emberfall           843.0     13014.0
# 4        4    156000.0   Meadowlands  Dragonspire           807.0      8092.0
# ...    ...         ...           ...          ...             ...         ...
# 1986  2333    117000.0   Meadowlands  Petalbridge           640.0      5400.0
# 1987  2334    195800.0   Meadowlands     Sunspire          1239.0      8400.0
# 1988  2337    214000.0   Meadowlands  Dragonspire          1138.0      8197.0
# 1989  2338    129500.0   Meadowlands    Emberfall           759.0      9100.0
# 1990  2339    153500.0   Meadowlands   Nighthaven           826.0     10140.0
#
#      ParcelSizeUnit  StructuralIntegrity ExteriorCharm  Craftsmanship  \
# 0              sqft                    6        Common              5
# 1              sqft                    5        Common              7
# 2              sqft                    7        Common              5
# 3              sqft                    5        Common              6
# 4              sqft                    8        Common              6
# ...             ...                  ...           ...            ...
# 1986           sqft                    7        Common              5
# 1987           sqft                    5      Gleaming              7
# 1988           sqft                    5      Gleaming              7
# 1989           sqft                    4        Common              5
# 1990           sqft                    6        Common              5
#
#       EraConstructed
# 0               1294
# 1               1442
# 2               1052
# 3               1512
# 4               1316
# ...              ...
# 1986            1287
# 1987            1774
# 1988            1645
# 1989            1372
# 1990            1500
#
# [1991 rows x 11 columns]
