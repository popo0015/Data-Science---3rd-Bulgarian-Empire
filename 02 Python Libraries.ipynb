# %%
import pandas as pd

# %%
df = pd.read_csv('Data/videogames.csv', sep=';')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       7590 non-null   float64
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'],
#       dtype='object')

# %%
df[['Global_Sales', 'Developer']]
# Out:
#        Global_Sales Developer
# 0             82.53  Nintendo
# 1             40.24       NaN
# 2             35.52  Nintendo
# 3             32.77  Nintendo
# 4             31.37       NaN
# ...             ...       ...
# 16714          0.01       NaN
# 16715          0.01       NaN
# 16716          0.01       NaN
# 16717          0.01       NaN
# 16718          0.01       NaN
#
# [16719 rows x 2 columns]

# %%
# Selects different columns
df_mean = df[['Global_Sales', 'JP_Sales', 'User_Count']]
df_mean.info()

# gets the average of the numeric columns
df_mean.mean()

df_mean.min()
df_mean.max()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Global_Sales  16719 non-null  float64
#  1   JP_Sales      16719 non-null  float64
#  2   User_Count    7590 non-null   float64
# dtypes: float64(3)
# memory usage: 392.0 KB
# Global_Sales       82.53
# JP_Sales           10.22
# User_Count      10665.00
# dtype: float64

# %%
df['Global_Sales'].median()
# Out:
# 0.17

# %%
df.describe()
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count     16450.000000  16719.000000  16719.000000  16719.000000
# mean       2006.487356      0.263330      0.145025      0.077602
# std           5.878995      0.813514      0.503283      0.308818
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2020.000000     41.360000     28.960000     10.220000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count   User_Score  \
# count  16719.000000  16719.000000   8137.000000   8137.000000  7590.000000
# mean       0.047332      0.533543     68.967679     26.360821     7.125046
# std        0.186710      1.547935     13.938165     18.980495     1.500006
# min        0.000000      0.010000     13.000000      3.000000     0.000000
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(x=df['Year_of_Release'])
plt.title('This is the title of the plot')
plt.show()

# %%
plt.hist(x=df['Critic_Score'], bins=20)
plt.title('This is histogram for the Critic Score')
plt.show()

# %%
plt.boxplot(x=df['Global_Sales'])
plt.title('This is boxplot for the Critic Score')
plt.show()

# %%
df_sales = df.loc[df['Global_Sales'] < 1]

# %%
df_sales
# Out:
#                                 Name Platform  Year_of_Release       Genre  \
# 2076                  NFL Fever 2002       XB           2000.0      Sports
# 2077                 Just Dance 2014     X360           2013.0        Misc
# 2078                NCAA Football 12     X360           2011.0      Sports
# 2079         The Simpsons: Hit & Run       GC           2003.0      Racing
# 2080                UFC Undisputed 3     X360           2012.0      Action
# ...                              ...      ...              ...         ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0      Action
# 16715               LMA Manager 2007     X360           2006.0      Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0   Adventure
# 16717               Spirits & Spells      GBA           2003.0    Platform
# 16718            Winning Post 8 2016      PSV           2016.0  Simulation
#
# ...

# %%
plt.hist(x=df_sales['Global_Sales'])
plt.title('This is boxplot for the Critic Score')
plt.show()

# %%
# Identify the name and critic score of action games released in 2008 that had a critic score of more than 90
df.loc[(df["Genre"] == "Action") & (df["Year_of_Release"] ==2008) & (df["Critic_Score"] > 90)]
# Out:
#                                          Name Platform  Year_of_Release  \
# 51                        Grand Theft Auto IV     X360           2008.0
# 57                        Grand Theft Auto IV      PS3           2008.0
# 147  Metal Gear Solid 4: Guns of the Patriots      PS3           2008.0
# 429             God of War: Chains of Olympus      PSP           2008.0
#
#       Genre                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 51   Action          Take-Two Interactive      6.76      3.07      0.14
# 57   Action          Take-Two Interactive      4.76      3.69      0.44
# 147  Action  Konami Digital Entertainment      2.63      1.71      0.83
# 429  Action   Sony Computer Entertainment      1.48      1.00      0.04
#
#      Other_Sales  Global_Sales  Critic_Score  Critic_Count  User_Score  \
# 51          1.03         11.01          98.0          86.0         7.9
# 57          1.61         10.50          98.0          64.0         7.5
# ...

# %%
df.loc[(df["Genre"] == 'Sports') & (df["Year_of_Release"] >= 2000) & (df["Year_of_Release"] <= 2010) & (df["EU_Sales"] >= 1) & (df["User_Score"] < 7), ["Name", "Publisher"]]
# Out:
#                            Name                     Publisher
# 393            FIFA Soccer 2003               Electronic Arts
# 649   pro evolution soccer 2011  Konami Digital Entertainment
# 697   Pro Evolution Soccer 2010  Konami Digital Entertainment
# 1165  Pro Evolution Soccer 2008  Konami Digital Entertainment

# %%
df.iloc[1:3,2:4]
# Out:
#    Year_of_Release     Genre
# 1           1985.0  Platform
# 2           2008.0    Racing

# %%
df.iloc[4:9, -3:]
# Out:
#    User_Count Developer Rating
# 4         NaN       NaN    NaN
# 5         NaN       NaN    NaN
# 6       431.0  Nintendo      E
# 7       129.0  Nintendo      E
# 8       594.0  Nintendo      E
